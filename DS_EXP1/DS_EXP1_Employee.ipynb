# %%
# import the required lib

import numpy as np
import pandas as pd

# %%
# read the data

df = pd.read_csv('/content/emp_promotion.csv')

# %%
# Visualize the dataset

df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.head(8)
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
# 5        58896          Analytics   region_2        Bachelor's      m
# 6        20379         Operations  region_20        Bachelor's      f
# 7        16290         Operations  region_34  Master's & above      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# ...

# %%
df.tail()
# Out:
#        employee_id         department     region         education gender  \
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 54803            sourcing                1   48                   3.0
# 54804               other                1   37                   2.0
# 54805               other                1   27                   5.0
# 54806            sourcing                1   29                   1.0
# 54807               other                1   27                   1.0
#
#        length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# ...

# %%
# Find the dtype

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
# descriptive stat

df.describe(include='all')
# Out:
#          employee_id         department    region   education gender  \
# count   54808.000000              54808     54808       52399  54808
# unique           NaN                  9        34           3      2
# top              NaN  Sales & Marketing  region_2  Bachelor's      m
# freq             NaN              16840     12343       36669  38496
# mean    39195.830627                NaN       NaN         NaN    NaN
# std     22586.581449                NaN       NaN         NaN    NaN
# min         1.000000                NaN       NaN         NaN    NaN
# 25%     19669.750000                NaN       NaN         NaN    NaN
# 50%     39225.500000                NaN       NaN         NaN    NaN
# 75%     58730.500000                NaN       NaN         NaN    NaN
# max     78298.000000                NaN       NaN         NaN    NaN
#
#        recruitment_channel  no_of_trainings           age  \
# count                54808     54808.000000  54808.000000
# ...

# %%
# Finding Null values

df.isnull()
# Out:
#        employee_id  department  region  education  gender  \
# 0            False       False   False      False   False
# 1            False       False   False      False   False
# 2            False       False   False      False   False
# 3            False       False   False      False   False
# 4            False       False   False      False   False
# ...            ...         ...     ...        ...     ...
# 54803        False       False   False      False   False
# 54804        False       False   False      False   False
# 54805        False       False   False      False   False
# 54806        False       False   False       True   False
# 54807        False       False   False      False   False
#
#        recruitment_channel  no_of_trainings    age  previous_year_rating  \
# 0                    False            False  False                 False
# 1                    False            False  False                 False
# ...

# %%
# Finding Null values

df.isnull().any()
# Out:
# employee_id             False
# department              False
# region                  False
# education                True
# gender                  False
# recruitment_channel     False
# no_of_trainings         False
# age                     False
# previous_year_rating     True
# length_of_service       False
# KPIs_met >80%           False
# awards_won?             False
# avg_training_score      False
# is_promoted             False
# dtype: bool

# %%
# Finding Null values

df.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
# Handling the null values

"""
2 ways to handle the null values
    1) removing the null value --- (dropna()) [10000 obs, 10 null values] or [10000 obs, 6000 null values]
    2) Replacing the null values --- (fillna()) [10000 obs, 1000 null values]
"""
# Out:
# '\n2 ways to handle the null values\n    1) removing the null value --- (dropna()) [10000 obs, 10 null values] or [10000 obs, 6000 null values]\n    2) Replacing the null values --- (fillna()) [10000 obs, 1000 null values]\n'

# %%
df['education'].mode()[0]
# Out:
# "Bachelor's"

# %%
df['previous_year_rating'].mean()
# Out:
# np.float64(3.329255780917055)

# %%
df['education'] = df['education'].fillna(df['education'].mode()[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-2730863227.py in <cell line: 0>()
# ----> 1 df['education'] = df['education'].fillna(df['education'].mode()[0])
#
# NameError: name 'df' is not defined

# %%
df['previous_year_rating'] = df['previous_year_rating'].fillna(df['previous_year_rating'].mean())

# %%
df.isnull().sum()
# Out:
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# is_promoted             0
# dtype: int64

# %%
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
# Selecting a specific data types
#1) Categorical Info** :  Holds important labels like city names, department names, grades etc.
#2) Feature Engineering** : Can be converted into numeric values using encoding techniques for modeling.
#3) Grouping/Aggregation** : Often used for `groupby()` operations.
#4) **Data Cleaning Target** : Usually requires cleaning (e.g., trimming, replacing text, fixing typos).
#5) **Needs Conversion** : Cannot be used directly in ML models; must be encoded to numeric first.

df.select_dtypes(exclude='object')
# Out:
#        employee_id  no_of_trainings  age  previous_year_rating  \
# 0            65438                1   35                   5.0
# 1            65141                1   30                   5.0
# 2             7513                1   34                   3.0
# 3             2542                2   39                   1.0
# 4            48945                1   45                   3.0
# ...            ...              ...  ...                   ...
# 54803         3030                1   48                   3.0
# 54804        74592                1   37                   2.0
# 54805        13918                1   27                   5.0
# 54806        13614                1   29                   1.0
# 54807        51526                1   27                   1.0
#
#        length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                      8              1            0                  49
# ...

# %%
# Selecting a specific data types

df.select_dtypes(include='object')
# Out:
#               department     region         education gender  \
# 0      Sales & Marketing   region_7  Master's & above      f
# 1             Operations  region_22        Bachelor's      m
# 2      Sales & Marketing  region_19        Bachelor's      m
# 3      Sales & Marketing  region_23        Bachelor's      m
# 4             Technology  region_26        Bachelor's      m
# ...                  ...        ...               ...    ...
# 54803         Technology  region_14        Bachelor's      m
# 54804         Operations  region_27  Master's & above      f
# 54805          Analytics   region_1        Bachelor's      m
# 54806  Sales & Marketing   region_9        Bachelor's      m
# 54807                 HR  region_22        Bachelor's      m
#
#       recruitment_channel
# 0                sourcing
# 1                   other
# 2                sourcing
# 3                   other
# 4                   other
# ...                   ...
# 54803            sourcing
# ...

# %%
df['department'].unique()
# Out:
# array(['Sales & Marketing', 'Operations', 'Technology', 'Analytics',
#        'R&D', 'Procurement', 'Finance', 'HR', 'Legal'], dtype=object)

# %%
df['department'].value_counts()
# Out:
# department
# Sales & Marketing    16840
# Operations           11348
# Technology            7138
# Procurement           7138
# Analytics             5352
# Finance               2536
# HR                    2418
# Legal                 1039
# R&D                    999
# Name: count, dtype: int64

# %%
df['recruitment_channel'].value_counts()
# Out:
# recruitment_channel
# other       30446
# sourcing    23220
# referred     1142
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
# Removing the unwanted columns

df = df.drop('employee_id',axis=1)
df.head()
# Out:
#           department     region         education gender recruitment_channel  \
# 0  Sales & Marketing   region_7  Master's & above      f            sourcing
# 1         Operations  region_22        Bachelor's      m               other
# 2  Sales & Marketing  region_19        Bachelor's      m            sourcing
# 3  Sales & Marketing  region_23        Bachelor's      m               other
# 4         Technology  region_26        Bachelor's      m               other
#
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   35                   5.0                  8
# 1                1   30                   5.0                  4
# 2                1   34                   3.0                  7
# 3                2   39                   1.0                 10
# 4                1   45                   3.0                  2
#
#    KPIs_met >80%  awards_won?  avg_training_score  is_promoted
# ...

# %%
# Encoding - 1)One Hot encoding, 2)Label encoding & 3)Manual encoding

# %%
# One hot encoding

pd.get_dummies(df['department'])
# Out:
#        Analytics  Finance     HR  Legal  Operations  Procurement    R&D  \
# 0          False    False  False  False       False        False  False
# 1          False    False  False  False        True        False  False
# 2          False    False  False  False       False        False  False
# 3          False    False  False  False       False        False  False
# 4          False    False  False  False       False        False  False
# ...          ...      ...    ...    ...         ...          ...    ...
# 54803      False    False  False  False       False        False  False
# 54804      False    False  False  False        True        False  False
# 54805       True    False  False  False       False        False  False
# 54806      False    False  False  False       False        False  False
# 54807      False    False   True  False       False        False  False
#
#        Sales & Marketing  Technology
# 0                   True       False
# ...

# %%
# Label encoding

# Apple, Shoes, Aeroplane
#   1      2       0

from sklearn.preprocessing import LabelEncoder

# %%
le1 = LabelEncoder()

# %%
df['department'] = le1.fit_transform(df['department'])

# %%
df.head()
# Out:
#    department     region         education gender recruitment_channel  \
# 0           7   region_7  Master's & above      f            sourcing
# 1           4  region_22        Bachelor's      m               other
# 2           7  region_19        Bachelor's      m            sourcing
# 3           7  region_23        Bachelor's      m               other
# 4           8  region_26        Bachelor's      m               other
#
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   35                   5.0                  8
# 1                1   30                   5.0                  4
# 2                1   34                   3.0                  7
# 3                2   39                   1.0                 10
# 4                1   45                   3.0                  2
#
#    KPIs_met >80%  awards_won?  avg_training_score  is_promoted
# 0              1            0                  49            0
# ...

# %%
le1.inverse_transform([4])
# Out:
# array(['Operations'], dtype=object)

# %%
# Step 1 Initialize

le2 = LabelEncoder()

# %%
# Step 2 Transform the values

df['region'] = le2.fit_transform(df['region'])

# %%
df.head()
# Out:
#    department  region         education gender recruitment_channel  \
# 0           7      31  Master's & above      f            sourcing
# 1           4      14        Bachelor's      m               other
# 2           7      10        Bachelor's      m            sourcing
# 3           7      15        Bachelor's      m               other
# 4           8      18        Bachelor's      m               other
#
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   35                   5.0                  8
# 1                1   30                   5.0                  4
# 2                1   34                   3.0                  7
# 3                2   39                   1.0                 10
# 4                1   45                   3.0                  2
#
#    KPIs_met >80%  awards_won?  avg_training_score  is_promoted
# 0              1            0                  49            0
# ...

# %%
le3 = LabelEncoder()

# %%
df['education'] = le3.fit_transform(df['education'])

df.head()
# Out:
#    department  region  education gender recruitment_channel  no_of_trainings  \
# 0           7      31          2      f            sourcing                1
# 1           4      14          0      m               other                1
# 2           7      10          0      m            sourcing                1
# 3           7      15          0      m               other                2
# 4           8      18          0      m               other                1
#
#    age  previous_year_rating  length_of_service  KPIs_met >80%  awards_won?  \
# 0   35                   5.0                  8              1            0
# 1   30                   5.0                  4              0            0
# 2   34                   3.0                  7              0            0
# 3   39                   1.0                 10              0            0
# 4   45                   3.0                  2              0            0
#
#    avg_training_score  is_promoted
# ...

# %%
# Manual encoding

# %%
df['gender'].unique()
# Out:
# array(['f', 'm'], dtype=object)

# %%
df['gender'] = df['gender'].replace({'f':0,'m':1})
df.head()
# Out:
# /tmp/ipython-input-39-3729952743.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['gender'] = df['gender'].replace({'f':0,'m':1})
#    department  region  education  gender recruitment_channel  no_of_trainings  \
# 0           7      31          2       0            sourcing                1
# 1           4      14          0       1               other                1
# 2           7      10          0       1            sourcing                1
# 3           7      15          0       1               other                2
# 4           8      18          0       1               other                1
#
#    age  previous_year_rating  length_of_service  KPIs_met >80%  awards_won?  \
# ...

# %%
df['recruitment_channel'].unique()
# Out:
# array(['sourcing', 'other', 'referred'], dtype=object)

# %%
df['recruitment_channel'] = df['recruitment_channel'].replace({'sourcing':0,'other':1,'referred':2})
df.head()
# Out:
# /tmp/ipython-input-41-4200040549.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['recruitment_channel'] = df['recruitment_channel'].replace({'sourcing':0,'other':1,'referred':2})
#    department  region  education  gender  recruitment_channel  \
# 0           7      31          2       0                    0
# 1           4      14          0       1                    1
# 2           7      10          0       1                    0
# 3           7      15          0       1                    1
# 4           8      18          0       1                    1
#
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   35                   5.0                  8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   department            54808 non-null  int64
#  1   region                54808 non-null  int64
#  2   education             54808 non-null  int64
#  3   gender                54808 non-null  int64
#  4   recruitment_channel   54808 non-null  int64
#  5   no_of_trainings       54808 non-null  int64
#  6   age                   54808 non-null  int64
#  7   previous_year_rating  54808 non-null  float64
#  8   length_of_service     54808 non-null  int64
#  9   KPIs_met >80%         54808 non-null  int64
#  10  awards_won?           54808 non-null  int64
#  11  avg_training_score    54808 non-null  int64
#  12  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 5.4 MB

# %%
# Split the dependent and independent data

x = df.drop('is_promoted',axis=1)
y = df['is_promoted']

# %%
# Split the data for training and testing

from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3,random_state=12)

# %%
xtrain.shape, xtest.shape
# Out:
# ((38365, 12), (16443, 12))

# %%
xtrain.head()
# Out:
#        department  region  education  gender  recruitment_channel  \
# 29677           5      18          1       0                    1
# 52628           4       6          0       1                    1
# 4041            3      11          0       1                    0
# 26140           7      12          0       1                    1
# 5671            7      14          2       0                    1
#
#        no_of_trainings  age  previous_year_rating  length_of_service  \
# 29677                1   23              3.329256                  1
# 52628                1   42              5.000000                  3
# 4041                 1   34              5.000000                  4
# 26140                1   38              5.000000                  7
# 5671                 1   40              3.000000                  3
#
#        KPIs_met >80%  awards_won?  avg_training_score
# 29677              1            0                  66
# ...

# %%
# Scaling the values 1) Standard scaler 2) MinMax scaler

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
n = MinMaxScaler()

# %%
xtrain_scaled = n.fit_transform(xtrain)

# %%
xtrain_scaled
# Out:
# array([[0.625     , 0.54545455, 0.5       , ..., 1.        , 0.        ,
#         0.45      ],
#        [0.5       , 0.18181818, 0.        , ..., 0.        , 0.        ,
#         0.4       ],
#        [0.375     , 0.33333333, 0.        , ..., 1.        , 0.        ,
#         0.33333333],
#        ...,
#        [0.875     , 0.72727273, 0.        , ..., 1.        , 0.        ,
#         0.15      ],
#        [0.875     , 0.45454545, 1.        , ..., 0.        , 0.        ,
#         0.18333333],
#        [0.875     , 0.39393939, 0.        , ..., 0.        , 0.        ,
#         0.21666667]])

# %%
s = StandardScaler()

# %%
xtrainScaled = s.fit_transform(xtrain)

# %%
xtrainScaled
# Out:
# array([[ 0.01001704,  0.29807729,  0.49361104, ...,  1.35289353,
#         -0.15437334,  0.19941564],
#        [-0.38905238, -1.07274417, -0.63000279, ..., -0.73915646,
#         -0.15437334, -0.02492184],
#        [-0.78812181, -0.50156856, -0.63000279, ...,  1.35289353,
#         -0.15437334, -0.32403847],
#        ...,
#        [ 0.80815589,  0.98348802, -0.63000279, ...,  1.35289353,
#         -0.15437334, -1.14660922],
#        [ 0.80815589, -0.04462807,  1.61722486, ..., -0.73915646,
#         -0.15437334, -0.99705091],
#        [ 0.80815589, -0.27309832, -0.63000279, ..., -0.73915646,
#         -0.15437334, -0.84749259]])

# %%
xtestScaled = s.transform(xtest)

# %%
xtestScaled
# Out:
# array([[-0.38905238,  1.897369  , -0.63000279, ..., -0.73915646,
#         -0.15437334, -0.24925932],
#        [ 0.80815589, -0.95850905, -0.63000279, ...,  1.35289353,
#         -0.15437334, -0.69793427],
#        [-1.98533008,  1.897369  , -0.63000279, ..., -0.73915646,
#         -0.15437334,  1.62021966],
#        ...,
#        [ 0.80815589,  1.44042851,  1.61722486, ...,  1.35289353,
#          6.47780257, -0.99705091],
#        [ 0.01001704, -0.50156856,  1.61722486, ..., -0.73915646,
#         -0.15437334,  0.2741948 ],
#        [ 0.80815589, -0.50156856,  1.61722486, ...,  1.35289353,
#         -0.15437334, -0.84749259]])
